# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats 
from scipy.stats import norm, skew 
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_transformer, ColumnTransformer
from sklearn.metrics import mean_squared_error
from sklearn import linear_model

# %%
#Открываем файлики
test = pd.read_csv('C:\\Users\\eatropynina\\Magnit\\test.csv', sep = ',', encoding='utf-8')
train = pd.read_csv('C:\\Users\\eatropynina\\Magnit\\train.csv', sep = ',', encoding='utf-8')
sample_submission = pd.read_csv('C:\\Users\\eatropynina\\Magnit\\sample_submission.csv', sep = ',', encoding='utf-8')

# %%
#Смотрим что у нас за данные
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     588 non-null    object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
plt.figure(figsize=(20,10))
sns.heatmap(train.isnull(),cbar=False,yticklabels=False,cmap = 'viridis')
# Out:
# <Axes: >

# %%
#Смотрим пропуски в данных
train.isnull().sum().sort_values(ascending=False).head(15)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageCond        81
# GarageType        81
# GarageFinish      81
# GarageQual        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# dtype: int64

# %%
#Удалим признаки с 1 по 12, в которых мало данных и много пропусков 
train = train.drop(columns=['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'MasVnrType','FireplaceQu', 'LotFrontage', 
                            'GarageYrBlt', 'GarageCond', 'GarageFinish', 'GarageType', 'GarageQual', 'BsmtFinType2'])
test = test.drop(columns=['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'MasVnrType','FireplaceQu', 'LotFrontage', 
                            'GarageYrBlt', 'GarageCond', 'GarageFinish', 'GarageType', 'GarageQual', 'BsmtFinType2'])

# %%
#Смотрим пропуски в данных
train.isnull().sum().sort_values(ascending=False).head(7)
# Out:
# BsmtExposure    38
# BsmtQual        37
# BsmtFinType1    37
# BsmtCond        37
# MasVnrArea       8
# Electrical       1
# GrLivArea        0
# dtype: int64

# %%
#Смотрим какие у нас данные в признаках с пропусками
train['BsmtExposure'].unique()
# Out:
# array(['No', 'Gd', 'Mn', 'Av', nan], dtype=object)

# %%
train['BsmtQual'].unique()
# Out:
# array(['Gd', 'TA', 'Ex', nan, 'Fa'], dtype=object)

# %%
train['BsmtFinType1'].unique()
# Out:
# array(['GLQ', 'ALQ', 'Unf', 'Rec', 'BLQ', nan, 'LwQ'], dtype=object)

# %%
train['BsmtCond'].unique()
# Out:
# array(['TA', 'Gd', nan, 'Fa', 'Po'], dtype=object)

# %%
train['MasVnrArea'].describe()
# Out:
# count    1452.000000
# mean      103.685262
# std       181.066207
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       166.000000
# max      1600.000000
# Name: MasVnrArea, dtype: float64

# %%
train['Electrical'].unique()
# Out:
# array(['SBrkr', 'FuseF', 'FuseA', 'FuseP', 'Mix', nan], dtype=object)

# %%
#Заполним пустые значения
train['MasVnrArea'].fillna(0, inplace=True)
test['MasVnrArea'].fillna(0, inplace=True)

train['BsmtExposure'].fillna('No', inplace=True)
test['BsmtExposure'].fillna('No', inplace=True)

train['BsmtQual'].fillna('No', inplace=True)
test['BsmtQual'].fillna('No', inplace=True)

train['BsmtCond'].fillna('No', inplace=True)
test['BsmtCond'].fillna('No', inplace=True)

train['BsmtFinType1'].fillna('Unf', inplace=True)
test['BsmtFinType1'].fillna('Unf', inplace=True)

train['Electrical'].fillna('No', inplace=True)
test['Electrical'].fillna('No', inplace=True)

# %%
#Смотрим какие есть числовые признаки, чтобы дальше их посмотреть детальнее и поискать в них выбросы
train.dtypes[train.dtypes != 'object']
# Out:
# Id                 int64
# MSSubClass         int64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageCars         int64
# GarageArea         int64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SalePrice          int64
# dtype: object

# %%
#Посмотрим выбросы у каждого признака, который хотя бы мало мальски их имеет. Определяю выбросы с помощью логики, божьей силы и туторов на ютубе
#MSSubClass - класс здания
plt.scatter(x='MSSubClass',y='SalePrice',data = train, color = 'blue')
#Тут вроде все ок

# %%
#LotArea - площадь самого участка
plt.scatter(x='LotArea',y='SalePrice',data = train, color = 'blue')
#Тут тоже есть выбросы

# %%
#249,313,335,706
train.query('LotArea>100000')
# Out:
#       Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 249  250          50       RL   159000   Pave      IR2         Low    AllPub
# 313  314          20       RL   215245   Pave      IR3         Low    AllPub
# 335  336         190       RL   164660   Grvl      IR1         HLS    AllPub
# 706  707          20       RL   115149   Pave      IR2         Low    AllPub
#
#     LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 249   CulDSac       Sev  ...             0         0           0        0
# 313    Inside       Sev  ...             0         0           0        0
# 335    Corner       Sev  ...             0         0           0        0
# 706   CulDSac       Sev  ...             0         0           0        0
#
#     MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 249     500       6    2007        WD         Normal    277000
# 313       0       6    2009        WD         Normal    375000
# 335     700       8    2008        WD         Normal    228950
# 706       0       6    2007        WD         Normal    302000
#
# [4 rows x 68 columns]

# %%
#OverallQual - качество материалов и отделки
plt.scatter(x='OverallQual',y='SalePrice',data = train, color = 'blue')

# %%
train.query('OverallQual==10').sort_values(by='SalePrice')
#Еще уберем 1298, 523
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 1298  1299          60       RL    63887   Pave      IR3         Bnk
# 523    524          60       RL    40094   Pave      IR1         Bnk
# 1442  1443          60       FV    11003   Pave      Reg         Lvl
# 583    584          75       RM    13500   Pave      Reg         Lvl
# 994    995          20       RL    12456   Pave      Reg         Lvl
# 825    826          20       RL    14803   Pave      Reg         Lvl
# 224    225          20       RL    13472   Pave      Reg         Lvl
# 515    516          20       RL    12220   Pave      Reg         Lvl
# 389    390          60       RL    12474   Pave      Reg         Lvl
# 58      59          60       RL    13682   Pave      IR2         HLS
# 591    592          60       RL    13478   Pave      IR1         Lvl
# 1243  1244          20       RL    13891   Pave      Reg         Lvl
# 1373  1374          20       RL    11400   Pave      Reg         Lvl
# 185    186          75       RM    22950   Pave      IR2         Lvl
# 440    441          20       RL    15431   Pave      Reg         Lvl
# 1169  1170          60       RL    35760   Pave      IR1         Lvl
# 1182  1183          60       RL    15623   Pave      IR1         Lvl
# 691    692          60       RL    21535   Pave      IR1         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 1298    AllPub    Corner       Gtl  ...             0         0           0
# 523     AllPub    Inside       Gtl  ...             0         0           0
# 1442    AllPub    Inside       Gtl  ...             0         0           0
# 583     AllPub    Inside       Gtl  ...             0         0           0
# 994     AllPub       FR2       Gtl  ...             0         0           0
# 825     AllPub    Inside       Gtl  ...             0         0           0
# 224     AllPub    Inside       Gtl  ...             0         0           0
# 515     AllPub    Inside       Gtl  ...             0         0           0
# 389     AllPub    Inside       Gtl  ...             0         0           0
# 58      AllPub   CulDSac       Gtl  ...            37         0           0
# 591     AllPub    Corner       Gtl  ...             0         0           0
# 1243    AllPub    Inside       Gtl  ...             0         0           0
# 1373    AllPub    Inside       Gtl  ...             0         0           0
# 185     AllPub    Inside       Gtl  ...             0         0         410
# 440     AllPub    Inside       Gtl  ...             0         0         170
# 1169    AllPub   CulDSac       Gtl  ...             0         0           0
# 1182    AllPub    Corner       Gtl  ...             0         0           0
# 691     AllPub    Corner       Gtl  ...             0         0           0
#
#      PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 1298      480       0       1    2008       New        Partial    160000
# 523         0       0      10    2007       New        Partial    184750
# 1442        0       0       4    2009        WD         Normal    310000
# 583         0       0       7    2008        WD         Normal    325000
# 994         0       0       7    2009        WD         Normal    337500
# 825         0       0       6    2008       New        Partial    385000
# 224         0       0       6    2009        WD         Normal    386250
# 515         0       0       9    2009       New        Partial    402861
# 389         0       0       8    2008       New        Partial    426000
# 58          0       0      10    2006       New        Partial    438780
# 591         0       0       6    2009     ConLI         Normal    451950
# 1243        0       0       9    2006       New        Partial    465000
# 1373        0       0       3    2007        WD         Normal    466500
# 185         0       0       6    2006        WD         Normal    475000
# 440         0       0       4    2009        WD         Normal    555000
# 1169        0       0       7    2006        WD         Normal    625000
# 1182      555       0       7    2007        WD        Abnorml    745000
# 691         0       0       1    2007        WD         Normal    755000
#
# [18 rows x 68 columns]

# %%
#OverallCond - общая оценка
plt.scatter(x='OverallCond',y='SalePrice',data = train, color = 'blue')

# %%
train.query('OverallCond == 2').sort_values(by='SalePrice')
#Добавим 378
# Out:
#       Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 398  399          30       RM     8967   Pave      Reg         Lvl    AllPub
# 250  251          30       RL     5350   Pave      IR1         Lvl    AllPub
# 88    89          50  C (all)     8470   Pave      IR1         Lvl    AllPub
# 676  677          70       RM     9600   Pave      Reg         Lvl    AllPub
# 378  379          20       RL    11394   Pave      Reg         Lvl    AllPub
#
#     LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 398    Corner       Gtl  ...             0         0           0        0
# 250    Inside       Gtl  ...             0         0           0        0
# 88     Corner       Gtl  ...           156         0           0        0
# 676    Inside       Gtl  ...            90         0           0        0
# 378    Corner       Gtl  ...             0         0           0        0
#
#     MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 398       0      11    2007        WD        Abnorml     67000
# 250     450       5    2010        WD         Normal     76500
# 88        0      10    2009     ConLD        Abnorml     85000
# 676       0       5    2006        WD         Normal     87000
# 378       0       6    2010       New        Partial    394432
#
# [5 rows x 68 columns]

# %%
train.query('OverallCond == 5').sort_values(by='SalePrice',ascending = False)
#Еще уберем 1182
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 1182  1183          60       RL    15623   Pave      IR1         Lvl
# 1169  1170          60       RL    35760   Pave      IR1         Lvl
# 898    899          20       RL    12919   Pave      IR1         Lvl
# 803    804          60       RL    13891   Pave      Reg         Lvl
# 1046  1047          60       RL    16056   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 462    463          20       RL     8281   Pave      IR1         Lvl
# 1100  1101          30       RL     8400   Pave      Reg         Bnk
# 812    813          20  C (all)     8712   Grvl      Reg         Bnk
# 705    706         190       RM     5600   Pave      Reg         Lvl
# 495    496          30  C (all)     7879   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 1182    AllPub    Corner       Gtl  ...             0         0           0
# 1169    AllPub   CulDSac       Gtl  ...             0         0           0
# 898     AllPub    Inside       Gtl  ...             0         0           0
# 803     AllPub    Inside       Gtl  ...             0         0         192
# 1046    AllPub    Inside       Gtl  ...             0         0           0
# ...        ...       ...       ...  ...           ...       ...         ...
# 462     AllPub    Inside       Gtl  ...           236         0           0
# 1100    AllPub    Inside       Gtl  ...             0         0           0
# 812     AllPub    Inside       Mod  ...             0         0           0
# 705     AllPub    Inside       Gtl  ...             0         0           0
# 495     AllPub    Inside       Gtl  ...           115         0           0
#
#      PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 1182      555       0       7    2007        WD        Abnorml    745000
# 1169        0       0       7    2006        WD         Normal    625000
# 898         0       0       3    2010       New        Partial    611657
# 803         0       0       1    2009       New        Partial    582933
# 1046        0       0       7    2006       New        Partial    556581
# ...       ...     ...     ...     ...       ...            ...       ...
# 462         0       0      12    2009        WD         Normal     62383
# 1100        0       0       1    2009        WD         Normal     60000
# 812         0      54       6    2010        WD         Alloca     55993
# 705         0    3500       7    2010        WD         Normal     55000
# 495         0       0      11    2009        WD        Abnorml     34900
#
# [821 rows x 68 columns]

# %%
train.query('OverallCond == 6').sort_values(by='SalePrice',ascending = False)
#Еще уберем 691
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 691    692          60       RL    21535   Pave      IR1         Lvl
# 688    689          20       RL     8089   Pave      Reg         HLS
# 608    609          70       RL    12168   Pave      Reg         HLS
# 654    655          20       RL    10437   Pave      IR1         Lvl
# 1024  1025          20       RL    15498   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 29      30          30       RM     6324   Pave      IR1         Lvl
# 874    875          50       RM     5720   Pave      Reg         Lvl
# 1432  1433          30       RL    10800   Pave      Reg         Lvl
# 710    711          30       RL     4130   Pave      IR1         Lvl
# 968    969          50       RM     5925   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 691     AllPub    Corner       Gtl  ...             0         0           0
# 688     AllPub    Inside       Gtl  ...             0         0           0
# 608     AllPub    Inside       Mod  ...             0         0           0
# 654     AllPub    Inside       Gtl  ...             0         0           0
# 1024    AllPub    Corner       Gtl  ...           174         0           0
# ...        ...       ...       ...  ...           ...       ...         ...
# 29      AllPub    Inside       Gtl  ...            87         0           0
# 874     AllPub    Inside       Gtl  ...             0         0           0
# 1432    AllPub    Inside       Gtl  ...             0         0           0
# 710     AllPub    Inside       Gtl  ...             0         0           0
# 968     AllPub    Inside       Gtl  ...             0         0           0
#
#      PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 691         0       0       1    2007        WD         Normal    755000
# 688         0       0      10    2007       New        Partial    392000
# 608         0       0       9    2007        WD         Alloca    359100
# 654         0       0       8    2008        WD         Normal    350000
# 1024        0       0       5    2008       COD        Abnorml    287000
# ...       ...     ...     ...     ...       ...            ...       ...
# 29          0       0       5    2008        WD         Normal     68500
# 874         0       0       8    2009        WD        Abnorml     66500
# 1432        0       0       8    2007        WD         Normal     64500
# 710         0       0       7    2008        WD         Normal     52000
# 968         0       0       5    2009        WD        Abnorml     37900
#
# [252 rows x 68 columns]

# %%
#YearBuilt - год постройки
plt.scatter(x='YearBuilt',y='SalePrice',data = train, color = 'blue')

# %%
train.query('YearBuilt > 1890 & YearBuilt < 1900').sort_values(by='SalePrice',ascending = False)
#Еще уберем 185
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 185    186          75       RM    22950   Pave      IR2         Lvl
# 583    584          75       RM    13500   Pave      Reg         Lvl
# 1292  1293          70       RM     6600   Pave      Reg         Lvl
# 809    810          75       RM     8100   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 185     AllPub    Inside       Gtl  ...             0         0         410
# 583     AllPub    Inside       Gtl  ...             0         0           0
# 1292    AllPub    Corner       Gtl  ...             0         0           0
# 809     AllPub    Corner       Gtl  ...             0         0           0
#
#      PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 185         0       0       6    2006        WD         Normal    475000
# 583         0       0       7    2008        WD         Normal    325000
# 1292        0       0      12    2009        WD         Normal    107500
# 809         0       0      11    2009        WD         Normal    106000
#
# [4 rows x 68 columns]

# %%
#YearRemodAdd - год, когда был сделан ремонт
plt.scatter(x='YearRemodAdd',y='SalePrice',data = train, color = 'blue')

# %%
train.query('YearRemodAdd > 1960 & YearRemodAdd < 1970').sort_values(by='SalePrice',ascending = False).head(3)
#Еще уберем 313
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 313    314          20       RL   215245   Pave      IR3         Low
# 1423  1424          80       RL    19690   Pave      IR1         Lvl
# 1250  1251          20       RL    11160   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 313     AllPub    Inside       Sev  ...             0         0           0
# 1423    AllPub   CulDSac       Gtl  ...             0         0           0
# 1250    AllPub    Corner       Gtl  ...             0         0           0
#
#      PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 313         0       0       6    2009        WD         Normal    375000
# 1423      738       0       8    2006        WD         Alloca    274970
# 1250        0       0       4    2010        WD         Normal    244000
#
# [3 rows x 68 columns]

# %%
train.query('YearRemodAdd > 1990 & YearRemodAdd < 2000').sort_values(by='SalePrice',ascending = False).head(3)
#Еще уберем 691,1182,1169
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 691    692          60       RL    21535   Pave      IR1         Lvl
# 1182  1183          60       RL    15623   Pave      IR1         Lvl
# 1169  1170          60       RL    35760   Pave      IR1         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 691     AllPub    Corner       Gtl  ...             0         0           0
# 1182    AllPub    Corner       Gtl  ...             0         0           0
# 1169    AllPub   CulDSac       Gtl  ...             0         0           0
#
#      PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 691         0       0       1    2007        WD         Normal    755000
# 1182      555       0       7    2007        WD        Abnorml    745000
# 1169        0       0       7    2006        WD         Normal    625000
#
# [3 rows x 68 columns]

# %%
#MasVnrArea - Тип облицовки
plt.scatter(x='MasVnrArea',y='SalePrice',data = train, color = 'blue')

# %%
train.query('MasVnrArea > 1500').sort_values(by='SalePrice',ascending = False).head(3)
#Еще уберем 297
# Out:
#       Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 297  298          60       FV     7399   Pave      IR1         Lvl    AllPub
#
#     LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 297    Inside       Gtl  ...             0         0         198        0
#
#     MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 297       0       6    2007        WD         Normal    239000
#
# [1 rows x 68 columns]

# %%
#BsmtFinSF1 - Квадратные футы с отделкой 1-го типа
plt.scatter(x='BsmtFinSF1',y='SalePrice',data = train, color = 'blue')

# %%
train.query('BsmtFinSF1 > 5000').sort_values(by='SalePrice',ascending = False).head(3)
#Еще уберем 1298
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 1298  1299          60       RL    63887   Pave      IR3         Bnk
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 1298    AllPub    Corner       Gtl  ...             0         0           0
#
#      PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 1298      480       0       1    2008       New        Partial    160000
#
# [1 rows x 68 columns]

# %%
##BsmtFinSF2 - Квадратные футы с отделкой 2-го типа
plt.scatter(x='BsmtFinSF2',y='SalePrice',data = train, color = 'blue')

# %%
train.query('BsmtFinSF2 > 1400').sort_values(by='SalePrice',ascending = False).head(3)
#Еще уберем 322
# Out:
#       Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 322  323          60       RL    10380   Pave      IR1         Lvl    AllPub
#
#     LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 322    Inside       Gtl  ...             0         0           0        0
#
#     MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 322       0       8    2007        WD         Normal    301000
#
# [1 rows x 68 columns]

# %%
#TotalBsmtSF - Общая площадь фундамента
plt.scatter(x='TotalBsmtSF',y='SalePrice',data = train, color = 'blue')

# %%
train.query('TotalBsmtSF > 5000').sort_values(by='SalePrice',ascending = False).head(3)
#Еще уберем 1298
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 1298  1299          60       RL    63887   Pave      IR3         Bnk
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 1298    AllPub    Corner       Gtl  ...             0         0           0
#
#      PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 1298      480       0       1    2008       New        Partial    160000
#
# [1 rows x 68 columns]

# %%
train.query('TotalBsmtSF > 2000').sort_values(by='SalePrice',ascending = False).head(3)
#Еще уберем 1182,691
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 691    692          60       RL    21535   Pave      IR1         Lvl
# 1182  1183          60       RL    15623   Pave      IR1         Lvl
# 898    899          20       RL    12919   Pave      IR1         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 691     AllPub    Corner       Gtl  ...             0         0           0
# 1182    AllPub    Corner       Gtl  ...             0         0           0
# 898     AllPub    Inside       Gtl  ...             0         0           0
#
#      PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 691         0       0       1    2007        WD         Normal    755000
# 1182      555       0       7    2007        WD        Abnorml    745000
# 898         0       0       3    2010       New        Partial    611657
#
# [3 rows x 68 columns]

# %%
#LowQualFinSF - Низкое качество готовой отделки
plt.scatter(x='LowQualFinSF',y='SalePrice',data = train, color = 'blue')

# %%
train.query('LowQualFinSF > 500').sort_values(by='SalePrice',ascending = False).head(3)
#Еще уберем 185
# Out:
#       Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 185  186          75       RM    22950   Pave      IR2         Lvl    AllPub
# 635  636         190       RH    10896   Pave      Reg         Bnk    AllPub
# 170  171          50       RM    12358   Pave      IR1         Lvl    AllPub
#
#     LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 185    Inside       Gtl  ...             0         0         410        0
# 635    Inside       Gtl  ...             0         0           0        0
# 170    Inside       Gtl  ...             0         0           0        0
#
#     MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 185       0       6    2006        WD         Normal    475000
# 635       0       3    2007        WD        Abnorml    200000
# 170       0       5    2007        WD         Normal    128500
#
# [3 rows x 68 columns]

# %%
#GrLivArea - площадь жилой зоны
plt.scatter(x='GrLivArea',y='SalePrice',data = train, color = 'blue')

# %%
train.query('GrLivArea > 4000').sort_values(by='SalePrice',ascending = False).head(4)
#Еще уберем 691, 1182, 523, 1298
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 691    692          60       RL    21535   Pave      IR1         Lvl
# 1182  1183          60       RL    15623   Pave      IR1         Lvl
# 523    524          60       RL    40094   Pave      IR1         Bnk
# 1298  1299          60       RL    63887   Pave      IR3         Bnk
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 691     AllPub    Corner       Gtl  ...             0         0           0
# 1182    AllPub    Corner       Gtl  ...             0         0           0
# 523     AllPub    Inside       Gtl  ...             0         0           0
# 1298    AllPub    Corner       Gtl  ...             0         0           0
#
#      PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 691         0       0       1    2007        WD         Normal    755000
# 1182      555       0       7    2007        WD        Abnorml    745000
# 523         0       0      10    2007       New        Partial    184750
# 1298      480       0       1    2008       New        Partial    160000
#
# [4 rows x 68 columns]

# %%
#BsmtFullBath - Ванные комнаты выше уровня земли (кол-во)
plt.scatter(x='BsmtFullBath',y='SalePrice',data = train, color = 'blue')

# %%
train.query('BsmtFullBath == 3').sort_values(by='SalePrice',ascending = False).head(4)
#Еще уберем 738
# Out:
#       Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 738  739          90       RL    10800   Pave      Reg         Lvl    AllPub
#
#     LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 738    Inside       Gtl  ...             0         0           0        0
#
#     MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 738       0       3    2009        WD         Alloca    179000
#
# [1 rows x 68 columns]

# %%
#BsmtHalfBath - полу-ванные комнаты
plt.scatter(x='BsmtHalfBath',y='SalePrice',data = train, color = 'blue')

# %%
train.query('BsmtHalfBath == 2').sort_values(by='SalePrice',ascending = False).head(4)
#Еще уберем 597, 954
# Out:
#       Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 597  598         120       RL     3922   Pave      Reg         Lvl    AllPub
# 954  955          90       RL     9400   Pave      IR1         Lvl    AllPub
#
#     LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 597    Inside       Gtl  ...             0         0           0        0
# 954   CulDSac       Gtl  ...             0         0           0        0
#
#     MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 597       0       2    2007       New        Partial    194201
# 954       0      10    2006        WD        AdjLand    127500
#
# [2 rows x 68 columns]

# %%
#BedroomAbvGr - кол-во спален
plt.scatter(x='BedroomAbvGr',y='SalePrice',data = train, color = 'blue')

# %%
train.query('BedroomAbvGr == 8').sort_values(by='SalePrice',ascending = False).head(4)
#Еще уберем 635
# Out:
#       Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 635  636         190       RH    10896   Pave      Reg         Bnk    AllPub
#
#     LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 635    Inside       Gtl  ...             0         0           0        0
#
#     MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 635       0       3    2007        WD        Abnorml    200000
#
# [1 rows x 68 columns]

# %%
#KitchenAbvGr - кол-во кухонь
plt.scatter(x='KitchenAbvGr',y='SalePrice',data = train, color = 'blue')

# %%
train.query('KitchenAbvGr == 3').sort_values(by='SalePrice',ascending = False).head(4)
#Еще уберем 48,809
# Out:
#       Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 48    49         190       RM     4456   Pave      Reg         Lvl    AllPub
# 809  810          75       RM     8100   Pave      Reg         Lvl    AllPub
#
#     LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 48     Inside       Gtl  ...           102         0           0        0
# 809    Corner       Gtl  ...             0         0           0        0
#
#     MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 48        0       6    2009       New        Partial    113000
# 809       0      11    2009        WD         Normal    106000
#
# [2 rows x 68 columns]

# %%
#TotRmsAbvGrd - общее кол-во комнат (без ванн. комнат)
plt.scatter(x='TotRmsAbvGrd',y='SalePrice',data = train, color = 'blue')

# %%
train.query('TotRmsAbvGrd == 14').sort_values(by='SalePrice',ascending = False).head(4)
#Еще уберем 635
# Out:
#       Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 635  636         190       RH    10896   Pave      Reg         Bnk    AllPub
#
#     LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 635    Inside       Gtl  ...             0         0           0        0
#
#     MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 635       0       3    2007        WD        Abnorml    200000
#
# [1 rows x 68 columns]

# %%
#Fireplaces - кол-во каминов
plt.scatter(x='Fireplaces',y='SalePrice',data = train, color = 'blue')

# %%
#GarageCars - сколько машин влезает в гараж
plt.scatter(x='GarageCars',y='SalePrice',data = train, color = 'blue')

# %%
#GarageArea - площадь гаража
plt.scatter(x='GarageArea',y='SalePrice',data = train, color = 'blue')

# %%
train.query('GarageArea > 1200').sort_values(by='SalePrice',ascending = False).head(6)
#Еще уберем 825,581,1190,1298,1061
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 825    826          20       RL    14803   Pave      Reg         Lvl
# 581    582          20       RL    12704   Pave      Reg         Lvl
# 1190  1191         190       RL    32463   Pave      Reg         Low
# 1298  1299          60       RL    63887   Pave      IR3         Bnk
# 1061  1062          30  C (all)    18000   Grvl      Reg         Low
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 825     AllPub    Inside       Gtl  ...             0         0           0
# 581     AllPub    Inside       Gtl  ...             0         0           0
# 1190    AllPub    Inside       Mod  ...             0         0           0
# 1298    AllPub    Corner       Gtl  ...             0         0           0
# 1061    AllPub    Inside       Gtl  ...             0         0           0
#
#      PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 825         0       0       6    2008       New        Partial    385000
# 581         0       0       8    2009       New        Partial    253293
# 1190        0       0       3    2007        WD         Normal    168000
# 1298      480       0       1    2008       New        Partial    160000
# 1061        0     560       8    2008     ConLD         Normal     81000
#
# [5 rows x 68 columns]

# %%
#WoodDeckSF - площадь деревянного настила
plt.scatter(x='WoodDeckSF',y='SalePrice',data = train, color = 'blue')

# %%
train.query('WoodDeckSF > 800').sort_values(by='SalePrice',ascending = False).head(6)
#Еще уберем 53
# Out:
#     Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 53  54          20       RL    50271   Pave      IR1         Low    AllPub
#
#    LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 53    Inside       Gtl  ...             0         0           0        0
#
#    MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 53       0      11    2006        WD         Normal    385000
#
# [1 rows x 68 columns]

# %%
#OpenPorchSF - площадь открытой веранды
plt.scatter(x='OpenPorchSF',y='SalePrice',data = train, color = 'blue')

# %%
train.query('OpenPorchSF > 500').sort_values(by='SalePrice',ascending = False).head(6)
#Еще уберем 583,1328,495
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 583    584          75       RM    13500   Pave      Reg         Lvl
# 1328  1329          50       RM    10440   Pave      Reg         Lvl
# 495    496          30  C (all)     7879   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 583     AllPub    Inside       Gtl  ...             0         0           0
# 1328    AllPub    Corner       Gtl  ...             0         0         480
# 495     AllPub    Inside       Gtl  ...           115         0           0
#
#      PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 583         0       0       7    2008        WD         Normal    325000
# 1328        0    1150       6    2008        WD         Normal    256000
# 495         0       0      11    2009        WD        Abnorml     34900
#
# [3 rows x 68 columns]

# %%
#EnclosedPorch - площадь закрытой веранды
plt.scatter(x='EnclosedPorch',y='SalePrice',data = train, color = 'blue')

# %%
train.query('EnclosedPorch > 500').sort_values(by='SalePrice',ascending = False).head(6)
#Еще уберем 197
# Out:
#       Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 197  198          75       RL    25419   Pave      Reg         Lvl    AllPub
#
#     LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 197    Corner       Gtl  ...           552         0           0      512
#
#     MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 197       0       3    2006        WD        Abnorml    235000
#
# [1 rows x 68 columns]

# %%
#3SsnPorch - площадь веранды на три сезона
plt.scatter(x='3SsnPorch',y='SalePrice',data = train, color = 'blue')

# %%
#ScreenPorch - площадь застекленной веранды
plt.scatter(x='ScreenPorch',y='SalePrice',data = train, color = 'blue')

# %%
#PoolArea - площадь бассейна
plt.scatter(x='PoolArea',y='SalePrice',data = train, color = 'blue')

# %%
#MiscVal - стоимость прочих дополнений
plt.scatter(x='MiscVal',y='SalePrice',data = train, color = 'blue')

# %%
#MoSold - сколько месяцев продавался
plt.scatter(x='MoSold',y='SalePrice',data = train, color = 'blue')

# %%
#YrSold - год продажи
plt.scatter(x='YrSold',y='SalePrice',data = train, color = 'blue')

# %%
#В итоге удаляем следующие номера из датасета, так как они ведут себя как выбросы: 49,54,186, 198, 250,298,314,323,336,379,496,524,582,584,598,636, 
#692, 707, 739,810,826,935,955,1062,1170,1183,1191, 1299, 1329
values=[49,54,186, 198, 250,298,314,323,336,379,496,524,582,584,598,636,692, 707, 739,810,826,935,955,1062,1170,1183,1191, 1299, 1329]

# %%
train = train[train.Id.isin(values) == False]

# %%
#Далее обобщим некоторые признаки путем их сложения\вычитания
#Вычисляем общий возраст дома
train['houseage'] = train['YrSold'] - train['YearBuilt']
test['houseage'] = test['YrSold'] - test['YearBuilt']

# %%
#Вычисляем как давно дом обновили
train['houseremodelage'] = train['YrSold'] - train['YearRemodAdd']
test['houseremodelage'] = test['YrSold'] - test['YearRemodAdd']

# %%
#Общая площадь дома
train['totalsf'] = train['1stFlrSF'] + train['2ndFlrSF'] + train['BsmtFinSF1'] + train['BsmtFinSF2']
test['totalsf'] = test['1stFlrSF'] + test['2ndFlrSF'] + test['BsmtFinSF1'] + test['BsmtFinSF2']

# %%
#Площадь подвальных помещений
train['totalarea'] = train['GrLivArea'] + train['TotalBsmtSF']
test['totalarea'] = test['GrLivArea'] + test['TotalBsmtSF']

# %%
#Площадь всех ванных
train['totalbaths'] = train['BsmtFullBath'] + train['FullBath'] + 0.5 * (train['BsmtHalfBath'] + train['HalfBath']) 
test['totalbaths'] = test['BsmtFullBath'] + test['FullBath'] + 0.5 * (test['BsmtHalfBath'] + test['HalfBath'])

# %%
#Площадь веранд в доме
train['totalporchsf'] = train['OpenPorchSF'] + train['3SsnPorch'] + train['EnclosedPorch'] + train['ScreenPorch'] + train['WoodDeckSF']
test['totalporchsf'] = test['OpenPorchSF'] + test['3SsnPorch'] + test['EnclosedPorch'] + test['ScreenPorch'] + test['WoodDeckSF']

# %%
#Удалим колонки, которые использовали выше для обобщения
train = train.drop(columns=['Id','YrSold', 'YearBuilt', 'YearRemodAdd', 
                                  '1stFlrSF', '2ndFlrSF', 'BsmtFinSF1', 'BsmtFinSF2', 
                                  'GrLivArea', 'TotalBsmtSF','BsmtFullBath', 'FullBath', 
                                  'BsmtHalfBath', 'HalfBath', 'OpenPorchSF', '3SsnPorch', 
                                  'EnclosedPorch', 'ScreenPorch','WoodDeckSF'])
test = test.drop(columns=['YrSold', 'YearBuilt', 'YearRemodAdd', '1stFlrSF', '2ndFlrSF', 
                                'BsmtFinSF1', 'BsmtFinSF2', 'GrLivArea', 'TotalBsmtSF','BsmtFullBath', 
                                'FullBath', 'BsmtHalfBath', 'HalfBath', 'OpenPorchSF', '3SsnPorch', 
                                'EnclosedPorch', 'ScreenPorch','WoodDeckSF'])

# %%
#У нас больше нет пропущенных значений! Ура!
plt.figure(figsize=(25,10))
sns.heatmap(train.isnull(),cbar=False,yticklabels=False,cmap = 'viridis')
# Out:
# <Axes: >

# %%
#Посмотрим на матрицу корреляций
corr = train.corr(numeric_only=True)
plt.figure(figsize=(18,11))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: >

# %%
#Видим, что распределение скошено. Модель линейной регрессии требует, чтобы зависимая переменная 
#следовала нормальному распределению, поэтому сделаем логарифмическое преобразование
sns.displot(train,x=train['SalePrice'],kde=True, color="blue", linewidth=1)
fig = plt.figure()
res = stats.probplot(train['SalePrice'], plot=plt)
plt.show()
# Out:
# C:\Users\eatropynina\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
train['SalePrice'] = np.log1p(train['SalePrice'])

# %%
#после преобразования - распределение стало ближе к нормальному
sns.displot(train,x=train['SalePrice'],kde=True, color="blue", linewidth=1)
fig = plt.figure()
res = stats.probplot(train['SalePrice'], plot=plt)
plt.show()
# Out:
# C:\Users\eatropynina\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
train.dtypes[train.dtypes=='object']
# Out:
# MSZoning         object
# Street           object
# LotShape         object
# LandContour      object
# Utilities        object
# LotConfig        object
# LandSlope        object
# Neighborhood     object
# Condition1       object
# Condition2       object
# BldgType         object
# HouseStyle       object
# RoofStyle        object
# RoofMatl         object
# Exterior1st      object
# Exterior2nd      object
# ExterQual        object
# ExterCond        object
# Foundation       object
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# Heating          object
# HeatingQC        object
# CentralAir       object
# Electrical       object
# KitchenQual      object
# Functional       object
# PavedDrive       object
# SaleType         object
# SaleCondition    object
# dtype: object

# %%
train.shape
# Out:
# (1431, 55)

# %%
train.head()
# Out:
#    MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope Neighborhood  ... MoSold SaleType SaleCondition  \
# 0    Inside       Gtl      CollgCr  ...      2       WD        Normal
# 1       FR2       Gtl      Veenker  ...      5       WD        Normal
# 2    Inside       Gtl      CollgCr  ...      9       WD        Normal
# 3    Corner       Gtl      Crawfor  ...      2       WD       Abnorml
# 4       FR2       Gtl      NoRidge  ...     12       WD        Normal
#
#    SalePrice  houseage  houseremodelage totalsf totalarea totalbaths  \
# 0  12.247699         5                5    2416      2566        3.5
# 1  12.109016        31               31    2240      2524        2.5
# 2  12.317171         7                6    2272      2706        3.5
# 3  11.849405        91               36    1933      2473        2.0
# 4  12.429220         8                8    2853      3343        3.5
#
#   totalporchsf
# 0           61
# 1          298
# 2           42
# 3          307
# 4          276
#
# [5 rows x 55 columns]

# %%
train['SalePrice'].describe()
# Out:
# count    1431.000000
# mean       12.016789
# std         0.389403
# min        10.471978
# 25%        11.774528
# 50%        11.995358
# 75%        12.264346
# max        13.323929
# Name: SalePrice, dtype: float64

# %%
train = pd.get_dummies(train, columns=['MSZoning', 'Street','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood','Condition1',
                                       'Condition2','BldgType','HouseStyle','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','ExterQual','ExterCond',
                                       'Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','Heating','HeatingQC','CentralAir',
                                      'Electrical','KitchenQual','Functional','PavedDrive','SaleType','SaleCondition'], drop_first=True)

# %%
test = pd.get_dummies(test, columns=['MSZoning', 'Street','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood','Condition1',
                                       'Condition2','BldgType','HouseStyle','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','ExterQual','ExterCond',
                                       'Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','Heating','HeatingQC','CentralAir',
                                      'Electrical','KitchenQual','Functional','PavedDrive','SaleType','SaleCondition'], drop_first=True)

# %%
#После проверки мы поняли, что у нас больше нет категориальных данных
train.dtypes[train.dtypes=='object']
# Out:
# Series([], dtype: object)

# %%
test.dtypes[test.dtypes=='object']
# Out:
# Series([], dtype: object)

# %%
#Смотрим размер датасета после onehotencoding и ужасаемся
train.shape
# Out:
# (1431, 196)

# %%
train.head()
# Out:
#    MSSubClass  LotArea  OverallQual  OverallCond  MasVnrArea  BsmtUnfSF  \
# 0          60     8450            7            5       196.0        150
# 1          20     9600            6            8         0.0        284
# 2          60    11250            7            5       162.0        434
# 3          70     9550            7            5         0.0        540
# 4          60    14260            8            5       350.0        490
#
#    LowQualFinSF  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  ...  \
# 0             0             3             1             8  ...
# 1             0             3             1             6  ...
# 2             0             3             1             6  ...
# 3             0             3             1             7  ...
# 4             0             4             1             9  ...
#
#    SaleType_ConLI  SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0           False           False         False         False         True
# 1           False           False         False         False         True
# 2           False           False         False         False         True
# 3           False           False         False         False         True
# 4           False           False         False         False         True
#
#    SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# 0                  False                 False                 False
# 1                  False                 False                 False
# 2                  False                 False                 False
# 3                  False                 False                 False
# 4                  False                 False                 False
#
#    SaleCondition_Normal  SaleCondition_Partial
# 0                  True                  False
# 1                  True                  False
# 2                  True                  False
# 3                 False                  False
# 4                  True                  False
#
# [5 rows x 196 columns]

# %%
y = train.SalePrice
X = train.drop(['SalePrice'], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr = model.fit(X_train, y_train)
print("R^2 is:", lr.score(X_test, y_test))
# Out:
# R^2 is: 0.8830997113887407

# %%
from sklearn.metrics import mean_squared_error
prediction = model.predict(X_test)

# %%
print("MSE is:", round(mean_squared_error(y_test, prediction),2))
# Out:
# MSE is: 0.02

# %%
actual_values = y_test
plt.scatter(prediction, actual_values, alpha=.75,
            color='b')  # alpha helps to show overlapping data
plt.xlabel('Predicted Price')
plt.ylabel('Actual Price')
plt.title('Linear Regression Model')
plt.show()
